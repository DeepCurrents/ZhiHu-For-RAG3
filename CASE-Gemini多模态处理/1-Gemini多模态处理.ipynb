# %%
from google import genai

client = genai.Client()
# 文字输出
response = client.models.generate_content(
    model="gemini-3.8-flash",
    contents="用中文解释AI大模型是如何工作的",
)

print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 如果我们把复杂的数学公式和代码剥离掉，AI大模型（特别是像ChatGPT这样的**大语言模型**）的工作原理，可以用一个非常形象的词来概括：**超级“文字接龙”**。
#
# 它的核心任务只有一件事：**根据前面已经出现的文字，预测下一个最可能出现的字（词）是什么。**
#
# 为了做到这一点，它经历了以下几个关键步骤：
#
# ---
#
# ### 第一步：把文字变成数字（Token与向量化）
# 计算机看不懂中文或英文，它只能看懂数字。
# 1. **分词（Tokenization）：** 模型会把一句话拆成一个个小碎片（称为 Token，可以是字、词或词根）。比如，“我喜欢吃苹果”可能被切分为“我 / 喜欢 / 吃 / 苹果”。
# 2. **向量化（Embedding）：** 模型把每个 Token 转换成一串长长的数字（数学上叫“向量”）。在这个数字空间里，**意思相近的词，位置也挨得很近**。比如，“猫”和“狗”的距离，会比“猫”和“飞机”的距离近得多。
#
# ---
#
# ### 第二步：大脑的核心——Transformer 架构与“注意力机制”
# 大模型之所以比以前的翻译软件聪明得多，是因为它采用了一种叫 **Transformer** 的技术，其精髓在于**“注意力机制”（Attention Mechanism）**。
#
# * **传统的AI：** 读一句话是一个字一个字往后读，读到句尾可能就忘了句头。
# * **大模型的注意力机制：** 它能**一眼看完整句话**，并且知道哪些词之间有更强烈的联系。
#     * *例子：* “小明把**苹果**递给了小红，因为**它**熟透了。”
#     * 模型通过注意力机制，能够准确计算出这里的“它”指的是“苹果”，而不是“小明”或“小红”。它能根据上下文准确理解多义词和复杂的句子结构。
#
# ---
#
# ### 第三步：大模型的“成长三部曲”（训练过程）
#
# 要让大模型变得聪明、听话，需要经过三个主要训练阶段：
#
# #### 1. 海量阅读（无监督预训练 - Pre-training）
# * **做法：** 给AI喂下全互联网几乎所有的公开文本（维基百科、书籍、新闻、代码、贴吧对话等），数据量以“TB”或“PB”计算。
# * **目的：** 这一步AI在疯狂做“文字接龙”练习。看到上文“床前明月”，它学会预测下文是“光”。通过阅读数万亿个词，它不仅学会了语言的语法，还“顺便”记住了人类世界的很多知识（历史、科学、常识）。
# * **结果：** 此时的模型是个**“博学但胡言乱语的怪人”**。你问它：“法国的首都是哪里？”，它可能会接着你的话写：“这是一道地理考试题，满分100分……”（因为它只顾着顺理成章地接话，不知道你在向它提问）。
#
# #### 2. 名师指导（监督微调 - SFT, Supervised Fine-Tuning）
# * **做法：** 人类专家编写几万到几十万高质量的“优质问答对”。比如：
#     * *问：*“法国的首都是哪里？”
#     * *答：*“法国的首都是巴黎。”
# * **目的：** 教会AI**理解指令**，让它明白人类是在向它提问，而它应该扮演一个有问必答的助手，而不是盲目接龙。
#
# #### 3. 立规矩与奖惩（人类反馈强化学习 - RLHF）
# * **做法：** 让AI针对同一个问题生成几个不同的回答，由人类来给这些回答打分（哪个答得好，哪个答得不好，哪个有危险/冒犯性言论）。
# * **目的：** 这就像训练小狗，做对了给骨头，做错了受惩罚。通过这种“胡萝卜加大棒”的机制，AI的回答会**越来越符合人类的偏好、道德规范和逻辑习惯**，变得既聪明又友善。
#
# ---
#
# ### 第四步：它现在是如何回答你的？（推理阶段）
#
# 当你现在向AI提问：“番茄炒蛋先放什么？”时，它在后台是这样工作的：
#
# 1. 理解你的问题（转换为向量，通过注意力机制分析）。
# 2. 计算接下来所有可能的汉字中，哪个概率最高。
# 3. 假设计算出“先”（35%）、“通”（20%）、“通”（15%）……它选择了概率最高的**“先”**。
# 4. 现在输入变成了：“番茄炒蛋先放什么？先”。
# 5. 接着算下一个字，可能是**“放”**。
# 6. 接着算下一个字，可能是**“油”**……
# 7. **一个字一个字地吐出来**（这就是为什么你看到AI打字是一顿一顿跳出来的原因），直到它输出了一个代表“停止”的特殊符号。
#
# ---
#
# ### 总结：AI 真的有思想吗？
#
# **没有。**
# 大模型并不真正“理解”它所说的话，它没有情感、没有意识，也没有肉体体验。
#
# 它之所以看起来像一个无所不知的哲学家或程序员，是因为它在极其庞大的数学网络（数千亿个参数）中，**把人类语言中蕴含的逻辑、规律和概率模拟到了极致**。它是一面镜子，折射出的是人类所有文明文本中凝聚的智慧。

# %%
from PIL import Image
# 图像理解
image = Image.open("dog_and_girl.jpeg")

# 注意：contents 变成了一个列表，里面同时放了图片对象和文字
response = client.models.generate_content(
    model="gemini-3.8-flash",
    contents=[image, "帮我解释下这张照片"]
)

print(response.text)
# Out:
# 这是一张非常**温暖、治愈且富有感染力**的人宠摄影作品。我们可以从以下几个维度来解读这张照片：
#
# ---
#
# ### 1. 核心主体与互动（情感表达）
# * **角色**：一位面带微笑的年轻女性和一只健壮的浅色犬（看起来是一只浅色的拉布拉多或金毛寻回犬）。
# * **互动动作**：女孩和狗狗正面对面坐在沙滩上，正在做一个经典的**“击掌”（High-five）或“握手”**动作。
# * **情感纽带**：女孩神情温柔专注，眼神里充满爱意；狗狗温顺信任地把爪子放在她的手上。这个瞬间定格了人与宠物之间高度的**默契、信任与陪伴**，生动诠释了“狗狗是人类最好的朋友”。
#
# ---
#
# ### 2. 环境与场景（空间氛围）
# * **地点**：一片开阔平缓的沙滩，远处是起伏的白色浪花和一望无际的海平线。
# * **氛围**：画面没有多余的杂物或其他人影，空旷的海滩和广阔的天空赋予了整张照片一种**静谧、自由和放松**的生活方式感。
#
# ---
#
# ### 3. 光影与构图（摄影美学）
# * **“黄金时刻”（Golden Hour）**：照片拍摄于日落或清晨时分。低角度的阳光从右侧照过来（侧逆光），在女孩的头发、肩膀和地面的沙粒上勾勒出一层金色的光晕（轮廓光），画面边缘泛着柔和的光斑，极具电影感。
# * **色彩搭配**：金黄色的阳光、浅灰蓝色的海面与细腻米白色的沙滩形成了柔和而高级的对比，色调温暖而不刺眼。
# * **低机位构图**：摄影师采用了贴近沙滩的低平视角拍摄，视线与女孩和狗狗保持平视，增强了观者的代入感，让人感觉仿佛就坐在他们身旁见证这一刻。
#
# ---
#
# ### 总结
# 这张照片之所以动人，是因为它把**美好的自然光线**、**宁静的海滩环境**与**纯粹真挚的跨物种情感**完美融合在了一起，传递出一种岁月静好、治愈心灵的力量。

# %%
# 视频理解
import time

# 1. 上传视频文件
print("正在上传视频...")
video_file = client.files.upload(file="car.mp4") # 汽车剐蹭视频
print(f"上传成功: {video_file.name}")

# 2. 等待视频处理 (关键步骤！)
# 视频上传后，Google 需要几秒钟在云端进行转码。
while video_file.state.name == "PROCESSING":
    print("视频处理中，请稍候...")
    time.sleep(2)
    video_file = client.files.get(name=video_file.name)

if video_file.state.name == "FAILED":
    raise ValueError("视频处理失败")

print("视频就绪，开始推理...")

# 3. 多模态推理
# 将上传好的 video_file 对象直接放入 contents 列表
response = client.models.generate_content(
    model="gemini-3.8-flash",
    contents=[
        video_file, 
        "详细描述视频里发生了什么？如果有对话，请把关键对话提取出来。"
    ]
)

print(response.text)

# 4. (可选) 删除云端文件以节省空间
# client.files.delete(name=video_file.name)
# Out:
# 正在上传视频...
# 上传成功: files/l3dok1krkuf6
# 视频处理中，请稍候...
# 视频处理中，请稍候...
# 视频就绪，开始推理...
# 视频展示了一对夫妻因地下车库转弯导致车辆刮蹭后的情况及事故现场，具体内容如下：
#
# ### 1. 车辆受损情况
# - 一辆白色SUV的右侧后门和后轮轮眉处有严重的刮蹭划痕，车门表面大面积凹陷变形，底漆脱落。
# - 男子在车旁仔细查看并比划受损范围，说明凹陷从后轮眉一直延伸至门把手下方，需要做钣金和补漆修复。
#
# ### 2. 关键对话提取
# - **女方**：“老公你说咱们这走保险呀，还是自己修呀？”
# - **男方**：“咱们没有车损险，咱们只能自己修了。”
#
# ### 3. 事故现场还原
# - 随后镜头来到地下车库转弯处，展示了车身刮蹭到的墙角，墙角处有明显的撞击脱落痕迹。男方指出这就是拐弯时不慎撞到的地方。
